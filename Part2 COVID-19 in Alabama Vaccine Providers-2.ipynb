# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
import warnings


# %matplotlib inline

# %%
file = pd.read_excel("C:/Users/dassi/Downloads/COVID-19 in Alabama Vaccine Providers-2.xlsx")
file
# Out:
#                            Name  \
# 0           1ST STREET PHARMACY
# 1    AAMU HEALTH AND COUNSELING
# 2       ABBEVILLE PHARMACY, LLC
# 3      ABC FAMILY MEDICINE, INC
# 4     ACCORDIA HEALTH- ROCKFORD
# ..                          ...
# 402        WINSTON CO HLTH DEPT
# 403  WRIGHT DRUG COMPANY HEFLIN
# 404   WYBENGA FAMILY HEALTHCARE
# 405        YERBY FREDERICK L MD
# 406             YORK DRUG STORE
#
#                                              Address     County
# 0         1070 1ST STREET NW, CHILDERSBURG, AL 35044  TALLADEGA
# 1                 4011 MERIDIAN ST, NORMAL, AL 35762    MADISON
# 2               615 OZARK ROAD , ABBEVILLE, AL 36310      HENRY
# 3           24 COUNTY ROAD 262, HANCEVILLE, AL 35077    CULLMAN
# 4                9518 US HWY 231, ROCKFORD, AL 35136      COOSA
# ..                                               ...        ...
# 402     110 LEGION RD, DOUBLE SPRINGS, AL 35553-2365    WINSTON
# ...

# %%
file.describe()
# Out:
#                        Name                                  Address  \
# count                   407                                      407
# unique                  407                                      406
# top     1ST STREET PHARMACY  220 HOSPITAL DR, JACKSON, AL 36545-2459
# freq                      1                                        2
#
#            County
# count         407
# unique         67
# top     JEFFERSON
# freq           28

# %%
# Group by the 'County' column and count the number of vaccine providers per county
county_provider_counts = file.groupby('County').size().reset_index(name='Number of Providers')

# Sort by the number of providers in descending order
county_provider_counts = county_provider_counts.sort_values(by='Number of Providers', ascending=False)

# Display the result
print(county_provider_counts)

# Optional: Plot the results using a bar chart for a better visual representation
import matplotlib.pyplot as plt
import seaborn as sns

# Create a bar plot
plt.figure(figsize=(12, 13))
sns.barplot(x='Number of Providers', y='County', data=county_provider_counts, palette='viridis')
plt.title('Number of Vaccine Providers by County in Alabama')
plt.xlabel('Number of Providers')
plt.ylabel('County')
plt.show()
# Out:
#         County  Number of Providers
# 36   JEFFERSON                   28
# 50  MONTGOMERY                   17
# 48      MOBILE                   17
# 44     MADISON                   13
# 47    MARSHALL                   13
# ..         ...                  ...
# 31      GREENE                    2
# 22        DALE                    2
# 5      BULLOCK                    2
# 18       COOSA                    1
# 65      WILCOX                    1
#
# [67 rows x 2 columns]
